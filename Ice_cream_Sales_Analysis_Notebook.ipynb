# %% [markdown]
# PROJECT SUMMARY
#
# You are a data analyst working for an ice cream company. Management is interested in improving the company's ice cream sales.
#
# The company has been collecting data about its sales—but not a lot. The available data is from an internal data source and is based on sales for 2019. You’ve been asked to review the data and provide some insight into the company’s ice cream sales. Ideally, management would like answers to the following questions:
#
# 1. What is the most popular flavor of ice cream?
# 2. How does temperature affect sales?
# 3. How do weekends affect sales?

# %% [markdown]
# ## What is the most popular flavor of icecream?			Lemon, 713 Sales

# %% [markdown]
# ![Distribution of ice cream unit sales by flavor.png](data:image/png;base64,...)

# %% [markdown]
# ## How does temperature affect sales?

# %% [markdown]
# The sales recieved when the temperature is above average are much more than those below average temperature.

# %% [markdown]
# ![Sales Above VS Sales Below Average Temperature.png](data:image/png;base64,...)

# %% [markdown]
# There is a string Correlation of 1, the higher the temperature, the higher the sales. Recommendation - Increase inventory during high temperature to maximize sales.

# %% [markdown]
# ![SALES vs. TEMPERATURE.png](data:image/png;base64,...)

# %% [markdown]
# ## How do weekends affect sales?

# %% [markdown]
# On Saturday, sales are double, but Sunday, the sales average the same as weekdays. Recommendation - Increase inventory on Saturdays to maximize sales.

# %% [markdown]
# ![Distribution of sales by day.png](data:image/png;base64,...)
